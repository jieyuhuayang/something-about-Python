# %% [markdown]
# # Matplotlib中的基本图表包括的元素
#
# - x轴和y轴 axis 水平和垂直的轴线
#
# - 轴标签 axisLabel 水平和垂直的轴标签
#
# - x轴和y轴刻度 tick 刻度标示坐标轴的分隔，包括最小刻度和最大刻度
#
# - x轴和y轴刻度标签 tick label 表示特定坐标轴的值
#
# - 绘图区域（坐标系） axes 实际绘图的区域
#
# ![注释](http://qiniu.s001.xin/matplot/tushi1.png "图示")

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-3, 3, 50)
y1 = 2*x + 1
y2 = x**2

plt.figure(figsize=(15,5))          #plt.figure()定义一个图像窗口.
plt.plot(x,y1)                      # 使用plt.plot画(x ,y)曲线. 
plt.show()                          #使用plt.show显示图像
#---------------------------------------------------------------------------------------------

plt.figure(num=3, figsize=(8, 5),)  #number 为 figure编号
plt.plot(x, y2)
plt.plot(x, y1, color='red', linewidth=5.0, linestyle='--')

plt.xlim((-1, 2))            #设置x轴范围
plt.ylim((-2, 3))
plt.xlabel('I am x')         #设置x轴名称
plt.ylabel('I am y')

new_ticks = np.linspace(-1, 2, 10)
plt.xticks(new_ticks)       # 使用plt.xticks设置x轴刻度
#r表示正则表达；\+空格转义空格 \alpha转义alpha
plt.yticks([-2, -1.8, -1, 1.22, 3],[r'$really\ bad\ \alpha$', r'$bad\ \alpha$', r'$normal\ \alpha$', r'$good\ \alpha$', r'$really\ good\ \alpha$'])  # 纵坐标换成文字

plt.show()

# %% [markdown]
# # 散点图
# 函数原型：
# ```python
# matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, edgecolors=None, *, data=None, **kwargs)
# ```
# - x，y：表示的是大小为(n,)的数组，也就是我们即将绘制散点图的数据点
#
# - s: 点的大小。是一个实数或者是一个数组大小为(n,)，这个是一个可选的参数。
#
# - c:表示的是颜色，也是一个可选项。默认是蓝色'b',表示的是标记的颜色，或者可以是一个表示颜色的字符，或者是一个长度为n的表示颜色的序列等等。但是c不可以是一个单独的RGB数字，也不可以是一个RGBA的序列。可以是他们的2维数组（只有一行）。
#
# - marker:表示的是标记的样式，默认的是'o'。![maker](https://img-blog.csdn.net/20151104234024896?watermark/2/text/aHR0cDovL2Jsb2cuY3Nkbi5uZXQv/font/5a6L5L2T/fontsize/400/fill/I0JBQkFCMA==/dissolve/70/gravity/Center)
#
# - cmap:Colormap实体或者是一个colormap的名字，cmap仅仅当c是一个浮点数数组的时候才使用。如果没有申明就是image.cmap
#
# - norm:Normalize实体来将数据亮度转化到0-1之间，也是只有c是一个浮点数的数组的时候才使用。如果没有申明，就是默认为colors.Normalize。
#
# - vmin,vmax:实数，当norm存在的时候忽略。用来进行亮度数据的归一化。
#
# - alpha：实数，0-1之间。
#
# - linewidths:也就是标记点的长度。

# %%
m =200 
X =np.random.randn(2,m) #产生2*200 高斯分布 均值为0 方差为1 
Y = (X[0,:]>0)*(X[1,:]>0)*1.0 + (X[0,:]<0)*(X[1,:]<0)
#可视化 jupyter notebook环境下
# %matplotlib inline 
plt.scatter(X[0,:],X[1,:],s=10,c=Y) #**
